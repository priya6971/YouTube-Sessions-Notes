# %% [markdown]
# **Import all the required packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Read the dataset**

# %%
dataframe = pd.read_csv('/content/winequality-red.csv')
dataframe.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
dataframe.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
set(dataframe['quality'])
# Out:
# {3, 4, 5, 6, 7, 8}

# %% [markdown]
# **Splitting the data into X(independent features) and y(target column)**

# %%
X = dataframe.drop(columns='quality', axis=1)
y = dataframe['quality']

# %%
X.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %% [markdown]
# **Split the data into training and testing set**

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %% [markdown]
# **Data Modeling**

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# **Model Predictions**

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([6, 6, 5, 5, 5, 6, 5, 5, 5, 5, 6, 5, 5, 5, 8, 6, 6, 5, 5, 5, 6, 5,
#        6, 6, 5, 5, 5, 5, 5, 5, 5, 5, 4, 6, 6, 5, 7, 7, 7, 6, 5, 6, 7, 6,
#        5, 6, 7, 6, 7, 5, 5, 5, 5, 6, 4, 6, 6, 6, 5, 6, 6, 6, 5, 6, 5, 7,
#        5, 5, 5, 6, 6, 6, 5, 5, 6, 5, 5, 6, 6, 7, 6, 5, 6, 6, 6, 7, 5, 6,
#        7, 5, 5, 7, 6, 5, 6, 7, 4, 8, 7, 5, 6, 5, 7, 5, 5, 6, 7, 5, 7, 6,
#        5, 5, 5, 6, 6, 6, 6, 6, 6, 5, 6, 6, 6, 5, 7, 5, 5, 6, 5, 6, 5, 5,
#        5, 4, 5, 7, 5, 6, 6, 7, 7, 5, 6, 8, 7, 4, 6, 6, 6, 5, 5, 6, 4, 5,
#        5, 5, 6, 7, 4, 6, 5, 7, 7, 5, 6, 6, 6, 5, 5, 5, 5, 4, 4, 7, 7, 5,
#        4, 5, 5, 6, 5, 5, 5, 5, 6, 6, 5, 6, 5, 5, 4, 7, 6, 5, 6, 6, 6, 7,
#        6, 5, 7, 5, 5, 6, 6, 6, 6, 7, 6, 6, 5, 7, 6, 6, 5, 5, 5, 6, 6, 6,
#        4, 6, 5, 7, 6, 7, 6, 6, 5, 5, 5, 5, 5, 6, 6, 6, 6, 7, 6, 6, 5, 6,
#        5, 7, 6, 5, 5, 6, 5, 5, 6, 6, 5, 5, 5, 6, 5, 7, 6, 5, 6, 5, 5, 5,
#        5, 7, 7, 6, 5, 6, 5, 5, 7, 7, 5, 5, 7, 5, 5, 5, 5, 5, 6, 8, 5, 6,
#        6, 5, 5, 5, 6, 5, 6, 7, 7, 6, 5, 6, 4, 7, 5, 6, 6, 6, 6, 5, 6, 6,
#        6, 7, 5, 5, 5, 6, 5, 5, 7, 5, 7, 6, 5, 5, 5, 5, 5, 5, 5, 6, 6, 6,
#        5, 7, 5, 5, 5, 7, 6, 6, 8, 6, 5, 5, 5, 5, 7, 5, 5, 5, 6, 5, 5, 6,
#        5, 5, 7, 6, 6, 5, 6, 7, 5, 5, 7, 5, 5, 6, 7, 5, 5, 6, 5, 6, 5, 6,
#        7, 5, 6, 5, 5, 6, 5, 5, 6, 6, 6, 5, 6, 5, 5, 5, 5, 6, 5, 7, 5, 6,
#        5, 7, 5, 6])

# %%
from sklearn import tree
plt.figure(figsize=(20, 20))
tree.plot_tree(model, filled=True)
# Out:
# [Text(0.5968823373211091, 0.9761904761904762, 'x[10] <= 10.525\ngini = 0.648\nsamples = 1199\nvalue = [7, 44, 501, 478, 155, 14]'),
#  Text(0.3797482949463327, 0.9285714285714286, 'x[6] <= 95.5\ngini = 0.551\nsamples = 721\nvalue = [4, 28, 417, 241, 29, 2]'),
#  Text(0.2362407759391771, 0.8809523809523809, 'x[9] <= 0.585\ngini = 0.576\nsamples = 634\nvalue = [4, 28, 338, 234, 28, 2]'),
#  Text(0.09783094812164579, 0.8333333333333334, 'x[10] <= 9.75\ngini = 0.495\nsamples = 278\nvalue = [3, 20, 184, 69, 2, 0]'),
#  Text(0.046958855098389984, 0.7857142857142857, 'x[10] <= 9.075\ngini = 0.409\nsamples = 173\nvalue = [1, 12, 129, 30, 1, 0]'),
#  Text(0.03264758497316637, 0.7380952380952381, 'x[6] <= 39.0\ngini = 0.602\nsamples = 14\nvalue = [0, 2, 5, 7, 0, 0]'),
#  Text(0.025491949910554562, 0.6904761904761905, 'x[9] <= 0.54\ngini = 0.494\nsamples = 9\nvalue = [0, 2, 1, 6, 0, 0]'),
#  Text(0.02191413237924866, 0.6428571428571429, 'x[1] <= 0.605\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0, 0, 0]'),
#  Text(0.018336314847942754, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.025491949910554562, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.029069767441860465, 0.6428571428571429, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.03980322003577817, 0.6904761904761905, 'x[9] <= 0.48\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.03622540250447227, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.04338103756708408, 0.6428571428571429, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.061270125223613595, 0.7380952380952381, 'x[8] <= 3.545\ngini = 0.367\nsamples = 159\nvalue = [1, 10, 124, 23, 1, 0]'),
#  Text(0.057692307692307696, 0.6904761904761905, 'x[1] <= 0.235\ngini = 0.348\nsamples = 156\nvalue = [1, 10, 124, 20, 1, 0]'),
#  Text(0.050536672629695883, 0.6428571428571429, 'x[9] <= 0.51\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.046958855098389984, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.05411449016100179, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.0648479427549195, 0.6428571428571429, 'x[1] <= 0.972\ngini = 0.333\nsamples = 154\nvalue = [1, 9, 124, 19, 1, 0]'),
#  Text(0.061270125223613595, 0.5952380952380952, 'x[9] <= 0.36\ngini = 0.324\nsamples = 153\nvalue = [0, 9, 124, 19, 1, 0]'),
#  Text(0.057692307692307696, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.0648479427549195, 0.5476190476190477, 'x[0] <= 12.4\ngini = 0.316\nsamples = 152\nvalue = [0, 8, 124, 19, 1, 0]'),
#  Text(0.061270125223613595, 0.5, 'x[7] <= 0.997\ngini = 0.308\nsamples = 151\nvalue = [0, 7, 124, 19, 1, 0]'),
#  Text(0.04740608228980322, 0.4523809523809524, 'x[6] <= 79.25\ngini = 0.362\nsamples = 89\nvalue = [0, 2, 69, 17, 1, 0]'),
#  Text(0.03398926654740608, 0.40476190476190477, 'x[7] <= 0.997\ngini = 0.31\nsamples = 82\nvalue = [0, 2, 67, 12, 1, 0]'),
#  Text(0.017889087656529516, 0.35714285714285715, 'x[2] <= 0.3\ngini = 0.174\nsamples = 53\nvalue = [0, 1, 48, 4, 0, 0]'),
#  Text(0.007155635062611807, 0.30952380952380953, 'x[0] <= 8.3\ngini = 0.082\nsamples = 47\nvalue = [0, 1, 45, 1, 0, 0]'),
#  Text(0.0035778175313059034, 0.2619047619047619, 'gini = 0.0\nsamples = 42\nvalue = [0, 0, 42, 0, 0, 0]'),
#  Text(0.01073345259391771, 0.2619047619047619, 'x[5] <= 7.0\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 3, 1, 0, 0]'),
#  Text(0.007155635062611807, 0.21428571428571427, 'x[1] <= 0.672\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.0035778175313059034, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.01073345259391771, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.014311270125223614, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.028622540250447227, 0.30952380952380953, 'x[7] <= 0.996\ngini = 0.5\nsamples = 6\nvalue = [0, 0, 3, 3, 0, 0]'),
#  Text(0.025044722719141325, 0.2619047619047619, 'x[5] <= 15.0\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.02146690518783542, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.028622540250447227, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.03220035778175313, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.05008944543828265, 0.35714285714285715, 'x[2] <= 0.27\ngini = 0.492\nsamples = 29\nvalue = [0, 1, 19, 8, 1, 0]'),
#  Text(0.046511627906976744, 0.30952380952380953, 'x[5] <= 12.5\ngini = 0.576\nsamples = 21\nvalue = [0, 1, 11, 8, 1, 0]'),
#  Text(0.03935599284436494, 0.2619047619047619, 'x[6] <= 12.5\ngini = 0.514\nsamples = 12\nvalue = [0, 1, 8, 2, 1, 0]'),
#  Text(0.03577817531305903, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.04293381037567084, 0.21428571428571427, 'x[0] <= 6.75\ngini = 0.43\nsamples = 11\nvalue = [0, 0, 8, 2, 1, 0]'),
#  Text(0.03935599284436494, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.046511627906976744, 0.16666666666666666, 'x[6] <= 31.5\ngini = 0.34\nsamples = 10\nvalue = [0, 0, 8, 1, 1, 0]'),
#  Text(0.04293381037567084, 0.11904761904761904, 'x[1] <= 0.63\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 2, 1, 1, 0]'),
#  Text(0.03935599284436494, 0.07142857142857142, 'x[5] <= 8.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.03577817531305903, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.04293381037567084, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.046511627906976744, 0.07142857142857142, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.05008944543828265, 0.11904761904761904, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.05366726296958855, 0.2619047619047619, 'x[1] <= 0.67\ngini = 0.444\nsamples = 9\nvalue = [0, 0, 3, 6, 0, 0]'),
#  Text(0.05008944543828265, 0.21428571428571427, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.057245080500894455, 0.21428571428571427, 'x[2] <= 0.14\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 3, 1, 0, 0]'),
#  Text(0.05366726296958855, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.06082289803220036, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.05366726296958855, 0.30952380952380953, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.06082289803220036, 0.40476190476190477, 'x[7] <= 0.997\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 2, 5, 0, 0]'),
#  Text(0.057245080500894455, 0.35714285714285715, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.06440071556350627, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.07513416815742398, 0.4523809523809524, 'x[4] <= 0.072\ngini = 0.206\nsamples = 62\nvalue = [0, 5, 55, 2, 0, 0]'),
#  Text(0.07155635062611806, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.07871198568872988, 0.40476190476190477, 'x[1] <= 0.665\ngini = 0.182\nsamples = 61\nvalue = [0, 4, 55, 2, 0, 0]'),
#  Text(0.07155635062611806, 0.35714285714285715, 'x[10] <= 9.35\ngini = 0.043\nsamples = 45\nvalue = [0, 1, 44, 0, 0, 0]'),
#  Text(0.06797853309481217, 0.30952380952380953, 'x[1] <= 0.605\ngini = 0.219\nsamples = 8\nvalue = [0, 1, 7, 0, 0, 0]'),
#  Text(0.06440071556350627, 0.2619047619047619, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.07155635062611806, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.07513416815742398, 0.30952380952380953, 'gini = 0.0\nsamples = 37\nvalue = [0, 0, 37, 0, 0, 0]'),
#  Text(0.08586762075134168, 0.35714285714285715, 'x[0] <= 8.05\ngini = 0.477\nsamples = 16\nvalue = [0, 3, 11, 2, 0, 0]'),
#  Text(0.08228980322003578, 0.30952380952380953, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.08944543828264759, 0.30952380952380953, 'x[3] <= 3.1\ngini = 0.642\nsamples = 9\nvalue = [0, 3, 4, 2, 0, 0]'),
#  Text(0.08586762075134168, 0.2619047619047619, 'x[6] <= 43.5\ngini = 0.611\nsamples = 6\nvalue = [0, 3, 1, 2, 0, 0]'),
#  Text(0.08228980322003578, 0.21428571428571427, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]'),
#  Text(0.08944543828264759, 0.21428571428571427, 'x[8] <= 3.245\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.08586762075134168, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.09302325581395349, 0.16666666666666666, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.09302325581395349, 0.2619047619047619, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.0684257602862254, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.0684257602862254, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.0648479427549195, 0.6904761904761905, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.1487030411449016, 0.7857142857142857, 'x[1] <= 0.65\ngini = 0.581\nsamples = 105\nvalue = [2, 8, 55, 39, 1, 0]'),
#  Text(0.120304114490161, 0.7380952380952381, 'x[9] <= 0.475\ngini = 0.573\nsamples = 70\nvalue = [0, 5, 29, 35, 1, 0]'),
#  Text(0.10912343470483005, 0.6904761904761905, 'x[9] <= 0.4\ngini = 0.198\nsamples = 9\nvalue = [0, 1, 8, 0, 0, 0]'),
#  Text(0.10554561717352415, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.11270125223613596, 0.6428571428571429, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.13148479427549195, 0.6904761904761905, 'x[1] <= 0.575\ngini = 0.548\nsamples = 61\nvalue = [0, 4, 21, 35, 1, 0]'),
#  Text(0.11985688729874776, 0.6428571428571429, 'x[4] <= 0.102\ngini = 0.452\nsamples = 39\nvalue = [0, 2, 10, 27, 0, 0]'),
#  Text(0.11627906976744186, 0.5952380952380952, 'x[8] <= 3.415\ngini = 0.425\nsamples = 38\nvalue = [0, 1, 10, 27, 0, 0]'),
#  Text(0.11270125223613596, 0.5476190476190477, 'x[1] <= 0.525\ngini = 0.394\nsamples = 37\nvalue = [0, 0, 10, 27, 0, 0]'),
#  Text(0.10912343470483005, 0.5, 'x[1] <= 0.345\ngini = 0.444\nsamples = 30\nvalue = [0, 0, 10, 20, 0, 0]'),
#  Text(0.10554561717352415, 0.4523809523809524, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.11270125223613596, 0.4523809523809524, 'x[8] <= 3.195\ngini = 0.486\nsamples = 24\nvalue = [0, 0, 10, 14, 0, 0]'),
#  Text(0.10912343470483005, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.11627906976744186, 0.40476190476190477, 'x[0] <= 7.45\ngini = 0.444\nsamples = 21\nvalue = [0, 0, 7, 14, 0, 0]'),
#  Text(0.1073345259391771, 0.35714285714285715, 'x[10] <= 10.2\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 4, 2, 0, 0]'),
#  Text(0.1037567084078712, 0.30952380952380953, 'x[9] <= 0.56\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.1001788908765653, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.1073345259391771, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.11091234347048301, 0.30952380952380953, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.1252236135957066, 0.35714285714285715, 'x[1] <= 0.515\ngini = 0.32\nsamples = 15\nvalue = [0, 0, 3, 12, 0, 0]'),
#  Text(0.11806797853309481, 0.30952380952380953, 'x[8] <= 3.245\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 1, 11, 0, 0]'),
#  Text(0.11449016100178891, 0.2619047619047619, 'x[1] <= 0.445\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.11091234347048301, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.11806797853309481, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.12164579606440072, 0.2619047619047619, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.13237924865831843, 0.30952380952380953, 'x[0] <= 8.2\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.12880143112701253, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.13595706618962433, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.11627906976744186, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.11985688729874776, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.12343470483005367, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.14311270125223613, 0.6428571428571429, 'x[4] <= 0.074\ngini = 0.607\nsamples = 22\nvalue = [0, 2, 11, 8, 1, 0]'),
#  Text(0.13953488372093023, 0.5952380952380952, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.14669051878354203, 0.5952380952380952, 'x[6] <= 64.5\ngini = 0.633\nsamples = 16\nvalue = [0, 2, 5, 8, 1, 0]'),
#  Text(0.14311270125223613, 0.5476190476190477, 'x[3] <= 2.15\ngini = 0.66\nsamples = 10\nvalue = [0, 2, 5, 2, 1, 0]'),
#  Text(0.13595706618962433, 0.5, 'x[2] <= 0.27\ngini = 0.72\nsamples = 5\nvalue = [0, 2, 1, 1, 1, 0]'),
#  Text(0.13237924865831843, 0.4523809523809524, 'x[7] <= 0.995\ngini = 0.667\nsamples = 3\nvalue = [0, 0, 1, 1, 1, 0]'),
#  Text(0.12880143112701253, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.13595706618962433, 0.40476190476190477, 'x[5] <= 8.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.13237924865831843, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.13953488372093023, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.13953488372093023, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.15026833631484796, 0.5, 'x[7] <= 0.996\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.14669051878354203, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.15384615384615385, 0.4523809523809524, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.15026833631484796, 0.5476190476190477, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.1771019677996422, 0.7380952380952381, 'x[2] <= 0.22\ngini = 0.424\nsamples = 35\nvalue = [2, 3, 26, 4, 0, 0]'),
#  Text(0.16457960644007155, 0.6904761904761905, 'x[7] <= 0.994\ngini = 0.275\nsamples = 26\nvalue = [2, 1, 22, 1, 0, 0]'),
#  Text(0.16100178890876565, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.16815742397137745, 0.6428571428571429, 'x[4] <= 0.216\ngini = 0.218\nsamples = 25\nvalue = [2, 0, 22, 1, 0, 0]'),
#  Text(0.16457960644007155, 0.5952380952380952, 'x[5] <= 3.5\ngini = 0.156\nsamples = 24\nvalue = [1, 0, 22, 1, 0, 0]'),
#  Text(0.16100178890876565, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.16815742397137745, 0.5476190476190477, 'x[4] <= 0.069\ngini = 0.083\nsamples = 23\nvalue = [0, 0, 22, 1, 0, 0]'),
#  Text(0.16457960644007155, 0.5, 'x[7] <= 0.997\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.16100178890876565, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.16815742397137745, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.17173524150268335, 0.5, 'gini = 0.0\nsamples = 21\nvalue = [0, 0, 21, 0, 0, 0]'),
#  Text(0.17173524150268335, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.18962432915921287, 0.6904761904761905, 'x[0] <= 8.7\ngini = 0.642\nsamples = 9\nvalue = [0, 2, 4, 3, 0, 0]'),
#  Text(0.18246869409660108, 0.6428571428571429, 'x[1] <= 0.778\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 0, 2, 0, 0]'),
#  Text(0.17889087656529518, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.18604651162790697, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.1967799642218247, 0.6428571428571429, 'x[3] <= 2.85\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 1, 0, 0]'),
#  Text(0.19320214669051877, 0.5952380952380952, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.2003577817531306, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3746506037567084, 0.8333333333333334, 'x[1] <= 0.548\ngini = 0.592\nsamples = 356\nvalue = [1, 8, 154, 165, 26, 2]'),
#  Text(0.2872037119856887, 0.7857142857142857, 'x[9] <= 0.665\ngini = 0.588\nsamples = 196\nvalue = [0, 2, 66, 105, 21, 2]'),
#  Text(0.25268336314847945, 0.7380952380952381, 'x[10] <= 10.15\ngini = 0.563\nsamples = 85\nvalue = [0, 0, 40, 39, 6, 0]'),
#  Text(0.2334525939177102, 0.6904761904761905, 'x[4] <= 0.078\ngini = 0.564\nsamples = 67\nvalue = [0, 0, 25, 36, 6, 0]'),
#  Text(0.21645796064400716, 0.6428571428571429, 'x[9] <= 0.615\ngini = 0.571\nsamples = 33\nvalue = [0, 0, 17, 13, 3, 0]'),
#  Text(0.2075134168157424, 0.5952380952380952, 'x[3] <= 1.45\ngini = 0.346\nsamples = 9\nvalue = [0, 0, 2, 7, 0, 0]'),
#  Text(0.2039355992844365, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2110912343470483, 0.5476190476190477, 'x[8] <= 3.03\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 1, 7, 0, 0]'),
#  Text(0.2075134168157424, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2146690518783542, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.22540250447227192, 0.5952380952380952, 'x[0] <= 6.65\ngini = 0.531\nsamples = 24\nvalue = [0, 0, 15, 6, 3, 0]'),
#  Text(0.22182468694096602, 0.5476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.22898032200357782, 0.5476190476190477, 'x[10] <= 9.85\ngini = 0.449\nsamples = 21\nvalue = [0, 0, 15, 3, 3, 0]'),
#  Text(0.22182468694096602, 0.5, 'x[2] <= 0.105\ngini = 0.124\nsamples = 15\nvalue = [0, 0, 14, 1, 0, 0]'),
#  Text(0.2182468694096601, 0.4523809523809524, 'x[9] <= 0.645\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.2146690518783542, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.22182468694096602, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.22540250447227192, 0.4523809523809524, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 13, 0, 0, 0]'),
#  Text(0.23613595706618962, 0.5, 'x[3] <= 1.75\ngini = 0.611\nsamples = 6\nvalue = [0, 0, 1, 2, 3, 0]'),
#  Text(0.23255813953488372, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.23971377459749552, 0.4523809523809524, 'x[2] <= 0.275\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 0, 3, 0]'),
#  Text(0.23613595706618962, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.24329159212880144, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.2504472271914132, 0.6428571428571429, 'x[6] <= 65.5\ngini = 0.479\nsamples = 34\nvalue = [0, 0, 8, 23, 3, 0]'),
#  Text(0.24329159212880144, 0.5952380952380952, 'x[3] <= 1.65\ngini = 0.328\nsamples = 26\nvalue = [0, 0, 2, 21, 3, 0]'),
#  Text(0.23971377459749552, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.24686940966010734, 0.5476190476190477, 'x[6] <= 12.5\ngini = 0.278\nsamples = 25\nvalue = [0, 0, 1, 21, 3, 0]'),
#  Text(0.24329159212880144, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.2504472271914132, 0.5, 'x[4] <= 0.084\ngini = 0.219\nsamples = 24\nvalue = [0, 0, 0, 21, 3, 0]'),
#  Text(0.24686940966010734, 0.4523809523809524, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 0, 13, 0, 0]'),
#  Text(0.25402504472271914, 0.4523809523809524, 'x[5] <= 8.5\ngini = 0.397\nsamples = 11\nvalue = [0, 0, 0, 8, 3, 0]'),
#  Text(0.2504472271914132, 0.40476190476190477, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.25760286225402507, 0.40476190476190477, 'x[5] <= 17.0\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 0, 2, 3, 0]'),
#  Text(0.25402504472271914, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.26118067978533094, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.25760286225402507, 0.5952380952380952, 'x[5] <= 25.0\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 6, 2, 0, 0]'),
#  Text(0.25402504472271914, 0.5476190476190477, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.26118067978533094, 0.5476190476190477, 'x[9] <= 0.635\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0]'),
#  Text(0.25760286225402507, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.26475849731663686, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.27191413237924866, 0.6904761904761905, 'x[6] <= 60.0\ngini = 0.278\nsamples = 18\nvalue = [0, 0, 15, 3, 0, 0]'),
#  Text(0.26833631484794274, 0.6428571428571429, 'x[1] <= 0.51\ngini = 0.117\nsamples = 16\nvalue = [0, 0, 15, 1, 0, 0]'),
#  Text(0.26475849731663686, 0.5952380952380952, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 15, 0, 0, 0]'),
#  Text(0.27191413237924866, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.27549194991055453, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.321724060822898, 0.7380952380952381, 'x[4] <= 0.097\ngini = 0.573\nsamples = 111\nvalue = [0, 2, 26, 66, 15, 2]'),
#  Text(0.293716457960644, 0.6904761904761905, 'x[6] <= 16.5\ngini = 0.538\nsamples = 83\nvalue = [0, 1, 12, 53, 15, 2]'),
#  Text(0.2826475849731664, 0.6428571428571429, 'x[6] <= 14.0\ngini = 0.691\nsamples = 9\nvalue = [0, 0, 4, 2, 2, 1]'),
#  Text(0.27906976744186046, 0.5952380952380952, 'x[3] <= 1.75\ngini = 0.64\nsamples = 5\nvalue = [0, 0, 0, 2, 2, 1]'),
#  Text(0.27549194991055453, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.2826475849731664, 0.5476190476190477, 'x[4] <= 0.055\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 0, 2, 2, 0]'),
#  Text(0.27906976744186046, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.28622540250447226, 0.5, 'x[9] <= 0.71\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.2826475849731664, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.2898032200357782, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.28622540250447226, 0.5952380952380952, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.30478533094812166, 0.6428571428571429, 'x[8] <= 3.025\ngini = 0.482\nsamples = 74\nvalue = [0, 1, 8, 51, 13, 1]'),
#  Text(0.29338103756708406, 0.5952380952380952, 'x[9] <= 0.79\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 0, 2, 1]'),
#  Text(0.2898032200357782, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.29695885509839, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.3161896243291592, 0.5952380952380952, 'x[1] <= 0.215\ngini = 0.447\nsamples = 71\nvalue = [0, 1, 8, 51, 11, 0]'),
#  Text(0.3041144901610018, 0.5476190476190477, 'x[7] <= 0.998\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 2, 0]'),
#  Text(0.3005366726296959, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3076923076923077, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.3282647584973166, 0.5476190476190477, 'x[10] <= 10.45\ngini = 0.409\nsamples = 68\nvalue = [0, 1, 7, 51, 9, 0]'),
#  Text(0.3148479427549195, 0.5, 'x[7] <= 0.997\ngini = 0.343\nsamples = 60\nvalue = [0, 1, 6, 48, 5, 0]'),
#  Text(0.29874776386404295, 0.4523809523809524, 'x[10] <= 9.95\ngini = 0.611\nsamples = 18\nvalue = [0, 1, 3, 10, 4, 0]'),
#  Text(0.2844364937388193, 0.40476190476190477, 'x[3] <= 1.95\ngini = 0.667\nsamples = 6\nvalue = [0, 1, 3, 1, 1, 0]'),
#  Text(0.2808586762075134, 0.35714285714285715, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.2880143112701252, 0.35714285714285715, 'x[1] <= 0.375\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 0, 1, 1, 0]'),
#  Text(0.2844364937388193, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.29159212880143115, 0.30952380952380953, 'x[2] <= 0.38\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 1, 0]'),
#  Text(0.2880143112701252, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.295169946332737, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.31305903398926654, 0.40476190476190477, 'x[5] <= 15.5\ngini = 0.375\nsamples = 12\nvalue = [0, 0, 0, 9, 3, 0]'),
#  Text(0.3094812164579606, 0.35714285714285715, 'x[8] <= 3.39\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 0, 2, 3, 0]'),
#  Text(0.30590339892665475, 0.30952380952380953, 'x[4] <= 0.058\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.3023255813953488, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.3094812164579606, 0.2619047619047619, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.31305903398926654, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.31663685152057247, 0.35714285714285715, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.33094812164579607, 0.4523809523809524, 'x[9] <= 1.27\ngini = 0.176\nsamples = 42\nvalue = [0, 0, 3, 38, 1, 0]'),
#  Text(0.32737030411449014, 0.40476190476190477, 'x[6] <= 80.5\ngini = 0.136\nsamples = 41\nvalue = [0, 0, 3, 38, 0, 0]'),
#  Text(0.32379248658318427, 0.35714285714285715, 'x[6] <= 53.5\ngini = 0.095\nsamples = 40\nvalue = [0, 0, 2, 38, 0, 0]'),
#  Text(0.32021466905187834, 0.30952380952380953, 'gini = 0.0\nsamples = 32\nvalue = [0, 0, 0, 32, 0, 0]'),
#  Text(0.32737030411449014, 0.30952380952380953, 'x[1] <= 0.465\ngini = 0.375\nsamples = 8\nvalue = [0, 0, 2, 6, 0, 0]'),
#  Text(0.32379248658318427, 0.2619047619047619, 'x[5] <= 17.5\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 1, 6, 0, 0]'),
#  Text(0.32021466905187834, 0.21428571428571427, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.32737030411449014, 0.21428571428571427, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.33094812164579607, 0.2619047619047619, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.33094812164579607, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.334525939177102, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.3416815742397138, 0.5, 'x[7] <= 0.998\ngini = 0.594\nsamples = 8\nvalue = [0, 0, 1, 3, 4, 0]'),
#  Text(0.33810375670840787, 0.4523809523809524, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.34525939177101966, 0.4523809523809524, 'x[6] <= 59.5\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 0, 4, 0]'),
#  Text(0.3416815742397138, 0.40476190476190477, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.3488372093023256, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.34973166368515207, 0.6904761904761905, 'x[0] <= 11.45\ngini = 0.533\nsamples = 28\nvalue = [0, 1, 14, 13, 0, 0]'),
#  Text(0.34615384615384615, 0.6428571428571429, 'x[10] <= 9.25\ngini = 0.517\nsamples = 24\nvalue = [0, 1, 14, 9, 0, 0]'),
#  Text(0.33899821109123435, 0.5952380952380952, 'x[10] <= 8.9\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 1, 5, 0, 0]'),
#  Text(0.3354203935599284, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.3425760286225403, 0.5476190476190477, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.35330948121645794, 0.5952380952380952, 'x[6] <= 15.5\ngini = 0.426\nsamples = 18\nvalue = [0, 1, 13, 4, 0, 0]'),
#  Text(0.34973166368515207, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.35688729874776387, 0.5476190476190477, 'x[8] <= 2.84\ngini = 0.32\nsamples = 16\nvalue = [0, 1, 13, 2, 0, 0]'),
#  Text(0.35330948121645794, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.36046511627906974, 0.5, 'x[7] <= 0.996\ngini = 0.231\nsamples = 15\nvalue = [0, 0, 13, 2, 0, 0]'),
#  Text(0.35688729874776387, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.36404293381037567, 0.4523809523809524, 'x[0] <= 10.65\ngini = 0.133\nsamples = 14\nvalue = [0, 0, 13, 1, 0, 0]'),
#  Text(0.36046511627906974, 0.40476190476190477, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0, 0, 0]'),
#  Text(0.3676207513416816, 0.40476190476190477, 'x[8] <= 3.08\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.36404293381037567, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.37119856887298747, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.35330948121645794, 0.6428571428571429, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.4620974955277281, 0.7857142857142857, 'x[0] <= 9.95\ngini = 0.554\nsamples = 160\nvalue = [1, 6, 88, 60, 5, 0]'),
#  Text(0.42419499105545616, 0.7380952380952381, 'x[2] <= 0.135\ngini = 0.521\nsamples = 144\nvalue = [0, 5, 86, 50, 3, 0]'),
#  Text(0.3935599284436494, 0.6904761904761905, 'x[0] <= 6.95\ngini = 0.574\nsamples = 74\nvalue = [0, 4, 35, 33, 2, 0]'),
#  Text(0.37119856887298747, 0.6428571428571429, 'x[2] <= 0.025\ngini = 0.381\nsamples = 21\nvalue = [0, 1, 16, 4, 0, 0]'),
#  Text(0.3676207513416816, 0.5952380952380952, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 13, 0, 0, 0]'),
#  Text(0.3747763864042934, 0.5952380952380952, 'x[7] <= 0.996\ngini = 0.594\nsamples = 8\nvalue = [0, 1, 3, 4, 0, 0]'),
#  Text(0.37119856887298747, 0.5476190476190477, 'x[10] <= 9.9\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 3, 1, 0, 0]'),
#  Text(0.3676207513416816, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.3747763864042934, 0.5, 'x[3] <= 1.7\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.37119856887298747, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.37835420393559926, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.37835420393559926, 0.5476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.4159212880143113, 0.6428571428571429, 'x[10] <= 9.85\ngini = 0.567\nsamples = 53\nvalue = [0, 3, 19, 29, 2, 0]'),
#  Text(0.4033989266547406, 0.5952380952380952, 'x[5] <= 17.5\ngini = 0.573\nsamples = 35\nvalue = [0, 3, 17, 15, 0, 0]'),
#  Text(0.3962432915921288, 0.5476190476190477, 'x[3] <= 2.45\ngini = 0.55\nsamples = 25\nvalue = [0, 2, 9, 14, 0, 0]'),
#  Text(0.3926654740608229, 0.5, 'x[7] <= 0.997\ngini = 0.585\nsamples = 20\nvalue = [0, 2, 9, 9, 0, 0]'),
#  Text(0.3855098389982111, 0.4523809523809524, 'x[1] <= 0.665\ngini = 0.5\nsamples = 12\nvalue = [0, 2, 2, 8, 0, 0]'),
#  Text(0.3819320214669052, 0.40476190476190477, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.389087656529517, 0.40476190476190477, 'x[10] <= 9.45\ngini = 0.667\nsamples = 6\nvalue = [0, 2, 2, 2, 0, 0]'),
#  Text(0.3855098389982111, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.3926654740608229, 0.35714285714285715, 'x[4] <= 0.106\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.389087656529517, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.3962432915921288, 0.30952380952380953, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.3998211091234347, 0.4523809523809524, 'x[6] <= 39.5\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 7, 1, 0, 0]'),
#  Text(0.3962432915921288, 0.40476190476190477, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.4033989266547406, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.3998211091234347, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.41055456171735244, 0.5476190476190477, 'x[7] <= 1.0\ngini = 0.34\nsamples = 10\nvalue = [0, 1, 8, 1, 0, 0]'),
#  Text(0.4069767441860465, 0.5, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.4141323792486583, 0.5, 'x[0] <= 8.15\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.41055456171735244, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.41771019677996424, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4284436493738819, 0.5952380952380952, 'x[4] <= 0.105\ngini = 0.37\nsamples = 18\nvalue = [0, 0, 2, 14, 2, 0]'),
#  Text(0.42486583184257604, 0.5476190476190477, 'x[0] <= 7.05\ngini = 0.219\nsamples = 16\nvalue = [0, 0, 2, 14, 0, 0]'),
#  Text(0.4212880143112701, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4284436493738819, 0.5, 'x[4] <= 0.087\ngini = 0.124\nsamples = 15\nvalue = [0, 0, 1, 14, 0, 0]'),
#  Text(0.42486583184257604, 0.4523809523809524, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 0, 13, 0, 0]'),
#  Text(0.43202146690518783, 0.4523809523809524, 'x[4] <= 0.092\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.4284436493738819, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.43559928443649376, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.43202146690518783, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.454830053667263, 0.6904761904761905, 'x[10] <= 9.15\ngini = 0.41\nsamples = 70\nvalue = [0, 1, 51, 17, 1, 0]'),
#  Text(0.4476744186046512, 0.6428571428571429, 'x[9] <= 1.445\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 4, 0, 0]'),
#  Text(0.44409660107334525, 0.5952380952380952, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.45125223613595705, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4619856887298748, 0.6428571428571429, 'x[6] <= 17.0\ngini = 0.368\nsamples = 65\nvalue = [0, 1, 50, 13, 1, 0]'),
#  Text(0.45840787119856885, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.4655635062611807, 0.5952380952380952, 'x[0] <= 6.95\ngini = 0.348\nsamples = 64\nvalue = [0, 1, 50, 13, 0, 0]'),
#  Text(0.44633273703041143, 0.5476190476190477, 'x[4] <= 0.164\ngini = 0.496\nsamples = 11\nvalue = [0, 0, 6, 5, 0, 0]'),
#  Text(0.44275491949910556, 0.5, 'x[5] <= 15.5\ngini = 0.444\nsamples = 9\nvalue = [0, 0, 6, 3, 0, 0]'),
#  Text(0.43917710196779963, 0.4523809523809524, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.44633273703041143, 0.4523809523809524, 'x[9] <= 0.595\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 1, 3, 0, 0]'),
#  Text(0.44275491949910556, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.44991055456171736, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.44991055456171736, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.4847942754919499, 0.5476190476190477, 'x[1] <= 0.647\ngini = 0.288\nsamples = 53\nvalue = [0, 1, 44, 8, 0, 0]'),
#  Text(0.46958855098389984, 0.5, 'x[2] <= 0.235\ngini = 0.383\nsamples = 31\nvalue = [0, 0, 23, 8, 0, 0]'),
#  Text(0.4606440071556351, 0.4523809523809524, 'x[5] <= 6.5\ngini = 0.124\nsamples = 15\nvalue = [0, 0, 14, 1, 0, 0]'),
#  Text(0.45706618962432916, 0.40476190476190477, 'x[1] <= 0.613\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.45348837209302323, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.4606440071556351, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.46422182468694095, 0.40476190476190477, 'gini = 0.0\nsamples = 13\nvalue = [0, 0, 13, 0, 0, 0]'),
#  Text(0.4785330948121646, 0.4523809523809524, 'x[4] <= 0.099\ngini = 0.492\nsamples = 16\nvalue = [0, 0, 9, 7, 0, 0]'),
#  Text(0.47137745974955275, 0.40476190476190477, 'x[8] <= 3.455\ngini = 0.444\nsamples = 9\nvalue = [0, 0, 3, 6, 0, 0]'),
#  Text(0.4677996422182469, 0.35714285714285715, 'x[7] <= 0.999\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 1, 6, 0, 0]'),
#  Text(0.46422182468694095, 0.30952380952380953, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.47137745974955275, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.4749552772808587, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.4856887298747764, 0.40476190476190477, 'x[9] <= 1.38\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 6, 1, 0, 0]'),
#  Text(0.4821109123434705, 0.35714285714285715, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6, 0, 0, 0]'),
#  Text(0.4892665474060823, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5, 0.5, 'x[9] <= 0.595\ngini = 0.087\nsamples = 22\nvalue = [0, 1, 21, 0, 0, 0]'),
#  Text(0.4964221824686941, 0.4523809523809524, 'x[0] <= 8.85\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0]'),
#  Text(0.4928443649373882, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5035778175313059, 0.4523809523809524, 'gini = 0.0\nsamples = 20\nvalue = [0, 0, 20, 0, 0, 0]'),
#  Text(0.5, 0.7380952380952381, 'x[3] <= 5.45\ngini = 0.57\nsamples = 16\nvalue = [1, 1, 2, 10, 2, 0]'),
#  Text(0.4964221824686941, 0.6904761904761905, 'x[10] <= 9.15\ngini = 0.459\nsamples = 14\nvalue = [1, 1, 2, 10, 0, 0]'),
#  Text(0.4892665474060823, 0.6428571428571429, 'x[9] <= 0.66\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0, 0, 0]'),
#  Text(0.4856887298747764, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0]'),
#  Text(0.4928443649373882, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5035778175313059, 0.6428571428571429, 'x[7] <= 0.998\ngini = 0.292\nsamples = 12\nvalue = [0, 1, 1, 10, 0, 0]'),
#  Text(0.5, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5071556350626119, 0.5952380952380952, 'x[5] <= 27.5\ngini = 0.165\nsamples = 11\nvalue = [0, 0, 1, 10, 0, 0]'),
#  Text(0.5035778175313059, 0.5476190476190477, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.5107334525939177, 0.5476190476190477, 'x[10] <= 9.7\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.5071556350626119, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5143112701252236, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.5035778175313059, 0.6904761904761905, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.5232558139534884, 0.8809523809523809, 'x[1] <= 0.3\ngini = 0.169\nsamples = 87\nvalue = [0, 0, 79, 7, 1, 0]'),
#  Text(0.5143112701252236, 0.8333333333333334, 'x[9] <= 0.645\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.5107334525939177, 0.7857142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5178890876565295, 0.7857142857142857, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5322003577817531, 0.8333333333333334, 'x[9] <= 1.175\ngini = 0.131\nsamples = 85\nvalue = [0, 0, 79, 6, 0, 0]'),
#  Text(0.5250447227191414, 0.7857142857142857, 'x[6] <= 109.5\ngini = 0.094\nsamples = 81\nvalue = [0, 0, 77, 4, 0, 0]'),
#  Text(0.5214669051878354, 0.7380952380952381, 'x[8] <= 3.175\ngini = 0.238\nsamples = 29\nvalue = [0, 0, 25, 4, 0, 0]'),
#  Text(0.5143112701252236, 0.6904761904761905, 'x[0] <= 8.05\ngini = 0.49\nsamples = 7\nvalue = [0, 0, 4, 3, 0, 0]'),
#  Text(0.5107334525939177, 0.6428571428571429, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.5178890876565295, 0.6428571428571429, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.5286225402504472, 0.6904761904761905, 'x[4] <= 0.072\ngini = 0.087\nsamples = 22\nvalue = [0, 0, 21, 1, 0, 0]'),
#  Text(0.5250447227191414, 0.6428571428571429, 'x[3] <= 2.1\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.5214669051878354, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.5286225402504472, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.5322003577817531, 0.6428571428571429, 'gini = 0.0\nsamples = 19\nvalue = [0, 0, 19, 0, 0, 0]'),
#  Text(0.5286225402504472, 0.7380952380952381, 'gini = 0.0\nsamples = 52\nvalue = [0, 0, 52, 0, 0, 0]'),
#  Text(0.539355992844365, 0.7857142857142857, 'x[10] <= 9.85\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 2, 0, 0]'),
#  Text(0.535778175313059, 0.7380952380952381, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.5429338103756708, 0.7380952380952381, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8140163796958855, 0.9285714285714286, 'x[9] <= 0.735\ngini = 0.652\nsamples = 478\nvalue = [3, 16, 84, 237, 126, 12]'),
#  Text(0.6980238148479427, 0.8809523809523809, 'x[6] <= 15.5\ngini = 0.632\nsamples = 320\nvalue = [3, 16, 70, 172, 54, 5]'),
#  Text(0.585644007155635, 0.8333333333333334, 'x[10] <= 11.45\ngini = 0.744\nsamples = 77\nvalue = [3, 7, 20, 22, 24, 1]'),
#  Text(0.5603756708407871, 0.7857142857142857, 'x[3] <= 1.95\ngini = 0.718\nsamples = 42\nvalue = [3, 7, 18, 10, 4, 0]'),
#  Text(0.5500894454382826, 0.7380952380952381, 'x[6] <= 10.5\ngini = 0.375\nsamples = 12\nvalue = [0, 0, 9, 0, 3, 0]'),
#  Text(0.5465116279069767, 0.6904761904761905, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.5536672629695886, 0.6904761904761905, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 9, 0, 0, 0]'),
#  Text(0.5706618962432916, 0.7380952380952381, 'x[1] <= 0.965\ngini = 0.733\nsamples = 30\nvalue = [3, 7, 9, 10, 1, 0]'),
#  Text(0.5608228980322003, 0.6904761904761905, 'x[1] <= 0.585\ngini = 0.678\nsamples = 26\nvalue = [0, 6, 9, 10, 1, 0]'),
#  Text(0.5518783542039356, 0.6428571428571429, 'x[2] <= 0.61\ngini = 0.568\nsamples = 13\nvalue = [0, 2, 2, 8, 1, 0]'),
#  Text(0.5483005366726297, 0.5952380952380952, 'x[3] <= 2.25\ngini = 0.43\nsamples = 11\nvalue = [0, 2, 0, 8, 1, 0]'),
#  Text(0.5447227191413238, 0.5476190476190477, 'x[1] <= 0.525\ngini = 0.64\nsamples = 5\nvalue = [0, 2, 0, 2, 1, 0]'),
#  Text(0.5411449016100179, 0.5, 'x[1] <= 0.35\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 0, 1, 0]'),
#  Text(0.537567084078712, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5447227191413238, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0]'),
#  Text(0.5483005366726297, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5518783542039356, 0.5476190476190477, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.5554561717352415, 0.5952380952380952, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.5697674418604651, 0.6428571428571429, 'x[9] <= 0.565\ngini = 0.592\nsamples = 13\nvalue = [0, 4, 7, 2, 0, 0]'),
#  Text(0.5626118067978533, 0.5952380952380952, 'x[6] <= 10.0\ngini = 0.219\nsamples = 8\nvalue = [0, 1, 7, 0, 0, 0]'),
#  Text(0.5590339892665475, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.5661896243291592, 0.5476190476190477, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 7, 0, 0, 0]'),
#  Text(0.5769230769230769, 0.5952380952380952, 'x[10] <= 10.85\ngini = 0.48\nsamples = 5\nvalue = [0, 3, 0, 2, 0, 0]'),
#  Text(0.5733452593917711, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.5805008944543828, 0.5476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]'),
#  Text(0.5805008944543828, 0.6904761904761905, 'x[9] <= 0.57\ngini = 0.375\nsamples = 4\nvalue = [3, 1, 0, 0, 0, 0]'),
#  Text(0.5769230769230769, 0.6428571428571429, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0, 0]'),
#  Text(0.5840787119856887, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.610912343470483, 0.7857142857142857, 'x[9] <= 0.575\ngini = 0.552\nsamples = 35\nvalue = [0, 0, 2, 12, 20, 1]'),
#  Text(0.6019677996422182, 0.7380952380952381, 'x[6] <= 11.5\ngini = 0.48\nsamples = 15\nvalue = [0, 0, 1, 10, 4, 0]'),
#  Text(0.5948121645796064, 0.6904761904761905, 'x[7] <= 0.993\ngini = 0.18\nsamples = 10\nvalue = [0, 0, 0, 9, 1, 0]'),
#  Text(0.5912343470483006, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.5983899821109123, 0.6428571428571429, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 9, 0, 0]'),
#  Text(0.6091234347048301, 0.6904761904761905, 'x[1] <= 0.64\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 1, 1, 3, 0]'),
#  Text(0.6055456171735242, 0.6428571428571429, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.6127012522361359, 0.6428571428571429, 'x[9] <= 0.525\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0]'),
#  Text(0.6091234347048301, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.6162790697674418, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6198568872987478, 0.7380952380952381, 'x[7] <= 0.993\ngini = 0.345\nsamples = 20\nvalue = [0, 0, 1, 2, 16, 1]'),
#  Text(0.6162790697674418, 0.6904761904761905, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.6234347048300537, 0.6904761904761905, 'x[3] <= 1.95\ngini = 0.277\nsamples = 19\nvalue = [0, 0, 0, 2, 16, 1]'),
#  Text(0.6198568872987478, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.6270125223613596, 0.6428571428571429, 'x[6] <= 7.5\ngini = 0.198\nsamples = 18\nvalue = [0, 0, 0, 2, 16, 0]'),
#  Text(0.6234347048300537, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6305903398926654, 0.5952380952380952, 'x[10] <= 11.55\ngini = 0.111\nsamples = 17\nvalue = [0, 0, 0, 1, 16, 0]'),
#  Text(0.6270125223613596, 0.5476190476190477, 'x[3] <= 2.25\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.6234347048300537, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.6305903398926654, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.6341681574239714, 0.5476190476190477, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 0, 0, 15, 0]'),
#  Text(0.8104036225402504, 0.8333333333333334, 'x[2] <= 0.655\ngini = 0.56\nsamples = 243\nvalue = [0, 9, 50, 150, 30, 4]'),
#  Text(0.7701811270125224, 0.7857142857142857, 'x[1] <= 0.873\ngini = 0.54\nsamples = 234\nvalue = [0, 9, 48, 149, 24, 4]'),
#  Text(0.7112030411449016, 0.7380952380952381, 'x[9] <= 0.555\ngini = 0.517\nsamples = 222\nvalue = [0, 5, 43, 146, 24, 4]'),
#  Text(0.6663685152057245, 0.6904761904761905, 'x[8] <= 3.355\ngini = 0.592\nsamples = 44\nvalue = [0, 1, 17, 22, 4, 0]'),
#  Text(0.6520572450805009, 0.6428571428571429, 'x[8] <= 3.285\ngini = 0.515\nsamples = 20\nvalue = [0, 0, 3, 13, 4, 0]'),
#  Text(0.648479427549195, 0.5952380952380952, 'x[3] <= 2.35\ngini = 0.653\nsamples = 12\nvalue = [0, 0, 3, 5, 4, 0]'),
#  Text(0.6413237924865832, 0.5476190476190477, 'x[10] <= 11.45\ngini = 0.408\nsamples = 7\nvalue = [0, 0, 2, 5, 0, 0]'),
#  Text(0.6377459749552773, 0.5, 'x[0] <= 9.4\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.6341681574239714, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.6413237924865832, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.644901610017889, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.6556350626118068, 0.5476190476190477, 'x[5] <= 8.5\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 1, 0, 4, 0]'),
#  Text(0.6520572450805009, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.6592128801431127, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.6556350626118068, 0.5952380952380952, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8, 0, 0]'),
#  Text(0.6806797853309481, 0.6428571428571429, 'x[10] <= 12.2\ngini = 0.517\nsamples = 24\nvalue = [0, 1, 14, 9, 0, 0]'),
#  Text(0.6735241502683363, 0.5952380952380952, 'x[4] <= 0.089\ngini = 0.398\nsamples = 16\nvalue = [0, 1, 12, 3, 0, 0]'),
#  Text(0.6699463327370304, 0.5476190476190477, 'x[3] <= 3.35\ngini = 0.255\nsamples = 14\nvalue = [0, 1, 12, 1, 0, 0]'),
# ...
#  Text(0.7576028622540251, 0.07142857142857142, 'x[9] <= 0.675\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1, 0, 0]'),
#  Text(0.7540250447227191, 0.023809523809523808, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.761180679785331, 0.023809523809523808, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7647584973166368, 0.16666666666666666, 'x[3] <= 5.9\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.761180679785331, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.7683363148479427, 0.11904761904761904, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7522361359570662, 0.40476190476190477, 'x[8] <= 3.59\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.7486583184257602, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.7558139534883721, 0.35714285714285715, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7629695885509838, 0.4523809523809524, 'x[8] <= 3.34\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 2, 0, 0]'),
#  Text(0.759391771019678, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.7665474060822898, 0.40476190476190477, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.7808586762075134, 0.5476190476190477, 'x[4] <= 0.117\ngini = 0.521\nsamples = 13\nvalue = [0, 1, 8, 4, 0, 0]'),
#  Text(0.7737030411449016, 0.5, 'x[7] <= 0.996\ngini = 0.32\nsamples = 10\nvalue = [0, 0, 8, 2, 0, 0]'),
#  Text(0.7701252236135957, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7772808586762076, 0.4523809523809524, 'x[8] <= 3.455\ngini = 0.198\nsamples = 9\nvalue = [0, 0, 8, 1, 0, 0]'),
#  Text(0.7737030411449016, 0.40476190476190477, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0, 0, 0]'),
#  Text(0.7808586762075134, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.7880143112701252, 0.5, 'x[0] <= 7.6\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 2, 0, 0]'),
#  Text(0.7844364937388193, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.7915921288014311, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8148479427549195, 0.5952380952380952, 'x[9] <= 0.685\ngini = 0.301\nsamples = 70\nvalue = [0, 0, 2, 58, 7, 3]'),
#  Text(0.7987477638640429, 0.5476190476190477, 'x[5] <= 5.5\ngini = 0.19\nsamples = 58\nvalue = [0, 0, 2, 52, 4, 0]'),
#  Text(0.7951699463327371, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8023255813953488, 0.5, 'x[9] <= 0.615\ngini = 0.163\nsamples = 57\nvalue = [0, 0, 1, 52, 4, 0]'),
#  Text(0.7987477638640429, 0.4523809523809524, 'gini = 0.0\nsamples = 31\nvalue = [0, 0, 0, 31, 0, 0]'),
#  Text(0.8059033989266547, 0.4523809523809524, 'x[9] <= 0.645\ngini = 0.322\nsamples = 26\nvalue = [0, 0, 1, 21, 4, 0]'),
#  Text(0.8023255813953488, 0.40476190476190477, 'x[9] <= 0.635\ngini = 0.562\nsamples = 11\nvalue = [0, 0, 1, 6, 4, 0]'),
#  Text(0.7987477638640429, 0.35714285714285715, 'x[4] <= 0.068\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 1, 6, 2, 0]'),
#  Text(0.7951699463327371, 0.30952380952380953, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8023255813953488, 0.30952380952380953, 'x[4] <= 0.076\ngini = 0.406\nsamples = 8\nvalue = [0, 0, 1, 6, 1, 0]'),
#  Text(0.7987477638640429, 0.2619047619047619, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.8059033989266547, 0.2619047619047619, 'x[6] <= 29.5\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 2, 1, 0]'),
#  Text(0.8023255813953488, 0.21428571428571427, 'x[6] <= 22.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0]'),
#  Text(0.7987477638640429, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8059033989266547, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0]'),
#  Text(0.8094812164579607, 0.21428571428571427, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8059033989266547, 0.35714285714285715, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.8094812164579607, 0.40476190476190477, 'gini = 0.0\nsamples = 15\nvalue = [0, 0, 0, 15, 0, 0]'),
#  Text(0.830948121645796, 0.5476190476190477, 'x[1] <= 0.555\ngini = 0.625\nsamples = 12\nvalue = [0, 0, 0, 6, 3, 3]'),
#  Text(0.8273703041144902, 0.5, 'x[7] <= 0.994\ngini = 0.54\nsamples = 10\nvalue = [0, 0, 0, 6, 1, 3]'),
#  Text(0.8202146690518783, 0.4523809523809524, 'x[7] <= 0.994\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 0, 1, 2]'),
#  Text(0.8166368515205724, 0.40476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.8237924865831843, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8345259391771019, 0.4523809523809524, 'x[10] <= 12.2\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 6, 0, 1]'),
#  Text(0.830948121645796, 0.40476190476190477, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0, 0]'),
#  Text(0.8381037567084079, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.8345259391771019, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.8291592128801432, 0.7380952380952381, 'x[6] <= 53.5\ngini = 0.653\nsamples = 12\nvalue = [0, 4, 5, 3, 0, 0]'),
#  Text(0.8220035778175313, 0.6904761904761905, 'x[4] <= 0.059\ngini = 0.5\nsamples = 6\nvalue = [0, 3, 0, 3, 0, 0]'),
#  Text(0.8184257602862254, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8255813953488372, 0.6428571428571429, 'x[10] <= 11.65\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 0, 1, 0, 0]'),
#  Text(0.8220035778175313, 0.5952380952380952, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0]'),
#  Text(0.8291592128801432, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8363148479427549, 0.6904761904761905, 'x[0] <= 9.95\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 5, 0, 0, 0]'),
#  Text(0.832737030411449, 0.6428571428571429, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0, 0]'),
#  Text(0.8398926654740608, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0]'),
#  Text(0.8506261180679785, 0.7857142857142857, 'x[6] <= 27.5\ngini = 0.494\nsamples = 9\nvalue = [0, 0, 2, 1, 6, 0]'),
#  Text(0.8470483005366727, 0.7380952380952381, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8542039355992844, 0.7380952380952381, 'x[10] <= 11.0\ngini = 0.245\nsamples = 7\nvalue = [0, 0, 0, 1, 6, 0]'),
#  Text(0.8506261180679785, 0.6904761904761905, 'x[0] <= 11.95\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.8470483005366727, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8542039355992844, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8577817531305904, 0.6904761904761905, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.9300089445438283, 0.8809523809523809, 'x[10] <= 11.65\ngini = 0.613\nsamples = 158\nvalue = [0, 0, 14, 65, 72, 7]'),
#  Text(0.8940071556350626, 0.8333333333333334, 'x[1] <= 0.375\ngini = 0.593\nsamples = 95\nvalue = [0, 0, 12, 50, 32, 1]'),
#  Text(0.8747763864042933, 0.7857142857142857, 'x[10] <= 11.35\ngini = 0.54\nsamples = 40\nvalue = [0, 0, 4, 12, 24, 0]'),
#  Text(0.8711985688729875, 0.7380952380952381, 'x[0] <= 6.65\ngini = 0.508\nsamples = 37\nvalue = [0, 0, 4, 9, 24, 0]'),
#  Text(0.8676207513416816, 0.6904761904761905, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8747763864042933, 0.6904761904761905, 'x[6] <= 93.0\ngini = 0.46\nsamples = 35\nvalue = [0, 0, 2, 9, 24, 0]'),
#  Text(0.8711985688729875, 0.6428571428571429, 'x[4] <= 0.073\ngini = 0.397\nsamples = 33\nvalue = [0, 0, 0, 9, 24, 0]'),
#  Text(0.8613595706618963, 0.5952380952380952, 'x[3] <= 2.35\ngini = 0.472\nsamples = 21\nvalue = [0, 0, 0, 8, 13, 0]'),
#  Text(0.8524150268336315, 0.5476190476190477, 'x[9] <= 0.805\ngini = 0.32\nsamples = 15\nvalue = [0, 0, 0, 3, 12, 0]'),
#  Text(0.8452593917710197, 0.5, 'x[7] <= 0.996\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0]'),
#  Text(0.8416815742397138, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.8488372093023255, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8595706618962433, 0.5, 'x[10] <= 10.7\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 0, 1, 11, 0]'),
#  Text(0.8559928443649374, 0.4523809523809524, 'x[1] <= 0.3\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.8524150268336315, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8595706618962433, 0.40476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8631484794275492, 0.4523809523809524, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 0, 0, 10, 0]'),
#  Text(0.870304114490161, 0.5476190476190477, 'x[8] <= 3.39\ngini = 0.278\nsamples = 6\nvalue = [0, 0, 0, 5, 1, 0]'),
#  Text(0.8667262969588551, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.8738819320214669, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8810375670840788, 0.5952380952380952, 'x[3] <= 1.7\ngini = 0.153\nsamples = 12\nvalue = [0, 0, 0, 1, 11, 0]'),
#  Text(0.8774597495527728, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8846153846153846, 0.5476190476190477, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 0, 11, 0]'),
#  Text(0.8783542039355993, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8783542039355993, 0.7380952380952381, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.9132379248658319, 0.7857142857142857, 'x[3] <= 4.0\ngini = 0.48\nsamples = 55\nvalue = [0, 0, 8, 38, 8, 1]'),
#  Text(0.9016100178890877, 0.7380952380952381, 'x[4] <= 0.057\ngini = 0.396\nsamples = 50\nvalue = [0, 0, 4, 38, 7, 1]'),
#  Text(0.889087656529517, 0.6904761904761905, 'x[8] <= 3.205\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 2, 1, 0, 1]'),
#  Text(0.8855098389982111, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.8926654740608229, 0.6428571428571429, 'x[8] <= 3.335\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1]'),
#  Text(0.889087656529517, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.8962432915921288, 0.5952380952380952, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9141323792486583, 0.6904761904761905, 'x[4] <= 0.09\ngini = 0.328\nsamples = 46\nvalue = [0, 0, 2, 37, 7, 0]'),
#  Text(0.9069767441860465, 0.6428571428571429, 'x[4] <= 0.071\ngini = 0.237\nsamples = 38\nvalue = [0, 0, 2, 33, 3, 0]'),
#  Text(0.9033989266547406, 0.5952380952380952, 'x[5] <= 11.0\ngini = 0.52\nsamples = 14\nvalue = [0, 0, 2, 9, 3, 0]'),
#  Text(0.8962432915921288, 0.5476190476190477, 'x[1] <= 0.5\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 2, 1, 1, 0]'),
#  Text(0.8926654740608229, 0.5, 'x[1] <= 0.43\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0]'),
#  Text(0.889087656529517, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.8962432915921288, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.8998211091234347, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]'),
#  Text(0.9105545617173524, 0.5476190476190477, 'x[7] <= 0.994\ngini = 0.32\nsamples = 10\nvalue = [0, 0, 0, 8, 2, 0]'),
#  Text(0.9069767441860465, 0.5, 'x[10] <= 11.15\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.9033989266547406, 0.4523809523809524, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9105545617173524, 0.4523809523809524, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.9141323792486583, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0, 0]'),
#  Text(0.9105545617173524, 0.5952380952380952, 'gini = 0.0\nsamples = 24\nvalue = [0, 0, 0, 24, 0, 0]'),
#  Text(0.9212880143112702, 0.6428571428571429, 'x[1] <= 0.505\ngini = 0.5\nsamples = 8\nvalue = [0, 0, 0, 4, 4, 0]'),
#  Text(0.9177101967799642, 0.5952380952380952, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 4, 0, 0]'),
#  Text(0.924865831842576, 0.5952380952380952, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4, 0]'),
#  Text(0.924865831842576, 0.7380952380952381, 'x[10] <= 11.0\ngini = 0.32\nsamples = 5\nvalue = [0, 0, 4, 0, 1, 0]'),
#  Text(0.9212880143112702, 0.6904761904761905, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0]'),
#  Text(0.9284436493738819, 0.6904761904761905, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0]'),
#  Text(0.9660107334525939, 0.8333333333333334, 'x[5] <= 18.5\ngini = 0.53\nsamples = 63\nvalue = [0, 0, 2, 15, 40, 6]'),
#  Text(0.9499105545617174, 0.7857142857142857, 'x[5] <= 8.0\ngini = 0.332\nsamples = 41\nvalue = [0, 0, 0, 5, 33, 3]'),
#  Text(0.9391771019677997, 0.7380952380952381, 'x[4] <= 0.057\ngini = 0.551\nsamples = 15\nvalue = [0, 0, 0, 4, 9, 2]'),
#  Text(0.9355992844364938, 0.6904761904761905, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9427549194991055, 0.6904761904761905, 'x[7] <= 0.996\ngini = 0.473\nsamples = 13\nvalue = [0, 0, 0, 2, 9, 2]'),
#  Text(0.9391771019677997, 0.6428571428571429, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 0, 6, 0]'),
#  Text(0.9463327370304114, 0.6428571428571429, 'x[7] <= 0.998\ngini = 0.653\nsamples = 7\nvalue = [0, 0, 0, 2, 3, 2]'),
#  Text(0.9427549194991055, 0.5952380952380952, 'x[1] <= 0.37\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 0, 2, 0, 2]'),
#  Text(0.9391771019677997, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2]'),
#  Text(0.9463327370304114, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0]'),
#  Text(0.9499105545617174, 0.5952380952380952, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0]'),
#  Text(0.960644007155635, 0.7380952380952381, 'x[4] <= 0.155\ngini = 0.145\nsamples = 26\nvalue = [0, 0, 0, 1, 24, 1]'),
#  Text(0.9570661896243292, 0.6904761904761905, 'x[1] <= 0.843\ngini = 0.077\nsamples = 25\nvalue = [0, 0, 0, 0, 24, 1]'),
#  Text(0.9534883720930233, 0.6428571428571429, 'gini = 0.0\nsamples = 24\nvalue = [0, 0, 0, 0, 24, 0]'),
#  Text(0.960644007155635, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1]'),
#  Text(0.964221824686941, 0.6904761904761905, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9821109123434705, 0.7857142857142857, 'x[7] <= 0.995\ngini = 0.665\nsamples = 22\nvalue = [0, 0, 2, 10, 7, 3]'),
#  Text(0.9749552772808586, 0.7380952380952381, 'x[1] <= 0.39\ngini = 0.444\nsamples = 9\nvalue = [0, 0, 0, 6, 0, 3]'),
#  Text(0.9713774597495528, 0.6904761904761905, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5, 0, 0]'),
#  Text(0.9785330948121646, 0.6904761904761905, 'x[6] <= 94.5\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 0, 3]'),
#  Text(0.9749552772808586, 0.6428571428571429, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 3]'),
#  Text(0.9821109123434705, 0.6428571428571429, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9892665474060823, 0.7380952380952381, 'x[2] <= 0.29\ngini = 0.592\nsamples = 13\nvalue = [0, 0, 2, 4, 7, 0]'),
#  Text(0.9856887298747764, 0.6904761904761905, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0]'),
#  Text(0.9928443649373881, 0.6904761904761905, 'x[0] <= 12.1\ngini = 0.46\nsamples = 10\nvalue = [0, 0, 2, 1, 7, 0]'),
#  Text(0.9892665474060823, 0.6428571428571429, 'x[8] <= 3.325\ngini = 0.219\nsamples = 8\nvalue = [0, 0, 0, 1, 7, 0]'),
#  Text(0.9856887298747764, 0.5952380952380952, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 5, 0]'),
#  Text(0.9928443649373881, 0.5952380952380952, 'x[7] <= 0.996\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 1, 2, 0]'),
#  Text(0.9892665474060823, 0.5476190476190477, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0]'),
#  Text(0.9964221824686941, 0.5476190476190477, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
#  Text(0.9964221824686941, 0.6428571428571429, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0]')]

# %% [markdown]
# **Top 20 sample data points from the dataframe**

# %%
sampleData = dataframe.head(20)
sampleData
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# 11            7.5             0.500         0.36             6.1      0.071
# 12            5.6             0.615         0.00             1.6      0.089
# 13            7.8             0.610         0.29             1.6      0.114
# 14            8.9             0.620         0.18             3.8      0.176
# 15            8.9             0.620         0.19             3.9      0.170
# 16            8.5             0.280         0.56             1.8      0.092
# 17            8.1             0.560         0.28             1.7      0.368
# 18            7.4             0.590         0.08             4.4      0.086
# 19            7.9             0.320         0.51             1.8      0.341
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  11.0                  34.0   0.9978  3.51       0.56
# 1                  25.0                  67.0   0.9968  3.20       0.68
# 2                  15.0                  54.0   0.9970  3.26       0.65
# 3                  17.0                  60.0   0.9980  3.16       0.58
# 4                  11.0                  34.0   0.9978  3.51       0.56
# 5                  13.0                  40.0   0.9978  3.51       0.56
# 6                  15.0                  59.0   0.9964  3.30       0.46
# 7                  15.0                  21.0   0.9946  3.39       0.47
# 8                   9.0                  18.0   0.9968  3.36       0.57
# 9                  17.0                 102.0   0.9978  3.35       0.80
# 10                 15.0                  65.0   0.9959  3.28       0.54
# 11                 17.0                 102.0   0.9978  3.35       0.80
# 12                 16.0                  59.0   0.9943  3.58       0.52
# 13                  9.0                  29.0   0.9974  3.26       1.56
# 14                 52.0                 145.0   0.9986  3.16       0.88
# 15                 51.0                 148.0   0.9986  3.17       0.93
# 16                 35.0                 103.0   0.9969  3.30       0.75
# 17                 16.0                  56.0   0.9968  3.11       1.28
# 18                  6.0                  29.0   0.9974  3.38       0.50
# 19                 17.0                  56.0   0.9969  3.04       1.08
#
#     alcohol  quality
# 0       9.4        5
# 1       9.8        5
# 2       9.8        5
# 3       9.8        6
# 4       9.4        5
# 5       9.4        5
# 6       9.4        5
# 7      10.0        7
# 8       9.5        7
# 9      10.5        5
# 10      9.2        5
# 11     10.5        5
# 12      9.9        5
# 13      9.1        5
# 14      9.2        5
# 15      9.2        5
# 16     10.5        7
# 17      9.3        5
# 18      9.0        4
# 19      9.2        6

# %%
X_sample = sampleData.drop(columns='quality', axis=1)
y_sample = sampleData['quality']

# %%
sampleModel = DecisionTreeClassifier()
sampleModel.fit(X_sample, y_sample)
# Out:
# DecisionTreeClassifier()

# %%
sampleData.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
X_sample.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
from sklearn import tree
plt.figure(figsize=(20, 20))
tree.plot_tree(sampleModel, filled=True)
# Out:
# [Text(0.5, 0.875, 'x[2] <= 0.435\ngini = 0.475\nsamples = 20\nvalue = [1, 14, 2, 3]'),
#  Text(0.25, 0.625, 'x[6] <= 25.0\ngini = 0.304\nsamples = 17\nvalue = [1, 14, 0, 2]'),
#  Text(0.125, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]'),
#  Text(0.375, 0.375, 'x[10] <= 9.05\ngini = 0.124\nsamples = 15\nvalue = [1, 14, 0, 0]'),
#  Text(0.25, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 14\nvalue = [0, 14, 0, 0]'),
#  Text(0.75, 0.625, 'x[8] <= 3.23\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 1]'),
#  Text(0.625, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.875, 0.375, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]')]

# %%
set(sampleData.quality)
# Out:
# {4, 5, 6, 7}
